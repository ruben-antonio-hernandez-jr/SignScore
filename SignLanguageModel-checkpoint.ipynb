# %%
####### TO RUN A PRE-TRAINED MODEL, FOLLOW THE INSTRUCTIONS BELOW #######
    # import necessary basic libraries (STEP 1)
    # establish holistic and drawing mediapipe variables (STEP 2)
    # run required functions (STEPS 3 - 6)
    # import tensorflow and keras packages (STEP 7)
    # establish model variable (STEP 8)
    # load pre-trained model (STEP 9)
    # import scipy stats (STEP 10)
    # run real-time testing (STEP 11)
    #
    #

# %%
# !pip install tensorflow==2.12.0 opencv-python scikit-learn matplotlib mediapipe
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (2.12.0)
# Requirement already satisfied: opencv-python in c:\users\user\miniconda3\envs\projects\lib\site-packages (4.8.1.78)
# Requirement already satisfied: scikit-learn in c:\users\user\miniconda3\envs\projects\lib\site-packages (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\user\miniconda3\envs\projects\lib\site-packages (3.6.0)
# Requirement already satisfied: mediapipe in c:\users\user\miniconda3\envs\projects\lib\site-packages (0.10.5)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.18)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.3.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.59.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.22.4)
# Requirement already satisfied: packaging in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (21.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: setuptools in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (63.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (4.37.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\miniconda3\envs\projects\lib\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: pycparser in c:\users\user\miniconda3\envs\projects\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.0.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.23.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.26.11)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\miniconda3\envs\projects\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)

# %%
### STEP 1 ###
from matplotlib import pyplot as plt
import numpy as np
import mediapipe as mp
import cv2
import os
import time

# %%
### STEP 2 ###
mpHolistic = mp.solutions.holistic
mpDrawing = mp.solutions.drawing_utils

# %%
### STEP 3 ###
def mp_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Write colors to RGB
    image.flags.writeable = False                  # Image unwritable
    results = model.process(image)                 # Process image
    image.flags.writeable = True                   # Image writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Convert colors back to BGR
    return image, results

# %%
### STEP 4 ###
def draw_landmarks(image, results):
    mpDrawing.draw_landmarks(image, results.pose_landmarks, mpHolistic.POSE_CONNECTIONS) # Draw pose connections
    mpDrawing.draw_landmarks(image, results.left_hand_landmarks, mpHolistic.HAND_CONNECTIONS) # Draw left hand connections
    mpDrawing.draw_landmarks(image, results.right_hand_landmarks, mpHolistic.HAND_CONNECTIONS) # Draw right hand connection

# %%
### STEP 5 ###
def draw_styled_landmarks(image, results):
    # Draw pose connections
    mpDrawing.draw_landmarks(image, results.pose_landmarks, mpHolistic.POSE_CONNECTIONS,
                             mpDrawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mpDrawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mpDrawing.draw_landmarks(image, results.left_hand_landmarks, mpHolistic.HAND_CONNECTIONS, 
                             mpDrawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mpDrawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mpDrawing.draw_landmarks(image, results.right_hand_landmarks, mpHolistic.HAND_CONNECTIONS, 
                             mpDrawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mpDrawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set model 
with mpHolistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image, results = mp_detection(frame, holistic)
        print(results)
        
        draw_styled_landmarks(image, results)

        cv2.imshow('OpenCV Feed', image)

        # Close window
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
### STEP 6 ###
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
np.save('0', result_test)

# %%
#Exported data
DATA_PATH = os.path.join('/Users/User/Desktop/SignScore/MP_Data') 

# Signs to train
actions1 = np.array(['hello', 'goodbye', 'thankyou'])
actions2 = np.array(['how', 'are you', 'take care'])

# Fifty videos for each sign
no_sequences = 50

# 10 frames per video
sequence_length = 10

# %%
def makeFiles(actions):
    for action in actions: 
        for sequence in range(1,no_sequences+1):
            try: 
                os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            except:
                pass

# %%
makeFiles(actions1)
makeFiles(actions2)

# %%
def collectData(actions):
    cap = cv2.VideoCapture(0)
    # Set mediapipe model 
    with mpHolistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

        # NEW LOOP
        # Loop through actions
        for action in actions:
            # Loop through sequences aka videos
            for sequence in range(1,no_sequences+1):
                # Loop through video length aka sequence length
                for frame_num in range(1,sequence_length+1):

                    # Read feed
                    ret, frame = cap.read()

                    # Make detections
                    image, results = mp_detection(frame, holistic)

                    # Draw landmarks
                    draw_styled_landmarks(image, results)

                    # NEW Apply wait logic
                    if frame_num == 0: 
                        cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                        cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        # Show to screen
                        cv2.imshow('OpenCV Feed', image)
                        cv2.waitKey(500)
                    else: 
                        cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        # Show to screen
                        cv2.imshow('OpenCV Feed', image)

                    # NEW Export keypoints
                    keypoints = extract_keypoints(results)
                    npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                    np.save(npy_path, keypoints)

                    # Break gracefully
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break

        cap.release()
        cv2.destroyAllWindows()

# %%
collectData(actions1)

# %%
collectData(actions2)

# %%
actions = np.concatenate((actions1, actions2), axis=None) #combine all signs into one array

# %%
label_map = {label:num for num, label in enumerate(actions)} #set labels
label_map
# Out:
# {'hello': 0,
#  'goodbye': 1,
#  'thankyou': 2,
#  'how': 3,
#  'are you': 4,
#  'take care': 5}

# %%
sequences, labels = [], []

# %%
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(1,sequence_length+1):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (300, 10, 258)

# %%
np.array(labels).shape
# Out:
# (300,)

# %%
X = np.array(sequences)
X.shape
# Out:
# (300, 10, 258)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05) #split data into training and testing sets
y_test.shape
# Out:
# (15, 6)

# %%
### STEP 7 ###
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, BatchNormalization, Flatten
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
### STEP 8 ###
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(10,258)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(X_train, y_train, epochs=1500, callbacks=[tb_callback]) #run training
model.summary()
# Out:
# Epoch 1/1500
# 9/9 [==============================] - 7s 29ms/step - loss: 1.7631 - categorical_accuracy: 0.1719
# Epoch 2/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 1.4343 - categorical_accuracy: 0.3860
# Epoch 3/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 1.2406 - categorical_accuracy: 0.4772
# Epoch 4/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0556 - categorical_accuracy: 0.5754
# Epoch 5/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.9715 - categorical_accuracy: 0.5439
# Epoch 6/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.8237 - categorical_accuracy: 0.6211
# Epoch 7/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6757 - categorical_accuracy: 0.7474
# Epoch 8/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6736 - categorical_accuracy: 0.6877
# Epoch 9/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6424 - categorical_accuracy: 0.7439
# Epoch 10/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4559 - categorical_accuracy: 0.8351
# Epoch 11/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4232 - categorical_accuracy: 0.8246
# Epoch 12/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4428 - categorical_accuracy: 0.8175
# Epoch 13/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3493 - categorical_accuracy: 0.8737
# Epoch 14/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3445 - categorical_accuracy: 0.8526
# Epoch 15/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4671 - categorical_accuracy: 0.8070
# Epoch 16/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4984 - categorical_accuracy: 0.7860
# Epoch 17/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.5588 - categorical_accuracy: 0.7895
# Epoch 18/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.4079 - categorical_accuracy: 0.8456
# Epoch 19/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.2990 - categorical_accuracy: 0.8667
# Epoch 20/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3043 - categorical_accuracy: 0.8772
# Epoch 21/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.2409 - categorical_accuracy: 0.8912
# Epoch 22/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.2628 - categorical_accuracy: 0.9088
# Epoch 23/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3575 - categorical_accuracy: 0.8737
# Epoch 24/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.5109 - categorical_accuracy: 0.7965
# Epoch 25/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4757 - categorical_accuracy: 0.8175
# Epoch 26/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2874 - categorical_accuracy: 0.9018
# Epoch 27/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2214 - categorical_accuracy: 0.9158
# Epoch 28/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2462 - categorical_accuracy: 0.9088
# Epoch 29/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2205 - categorical_accuracy: 0.9053
# Epoch 30/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.2186 - categorical_accuracy: 0.9193
# Epoch 31/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2702 - categorical_accuracy: 0.8982
# Epoch 32/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1772 - categorical_accuracy: 0.9333
# Epoch 33/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1953 - categorical_accuracy: 0.9088
# Epoch 34/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2042 - categorical_accuracy: 0.9158
# Epoch 35/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3099 - categorical_accuracy: 0.8947
# Epoch 36/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1876 - categorical_accuracy: 0.9263
# Epoch 37/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1602 - categorical_accuracy: 0.9439
# Epoch 38/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1863 - categorical_accuracy: 0.9228
# Epoch 39/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1442 - categorical_accuracy: 0.9298
# Epoch 40/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1188 - categorical_accuracy: 0.9579
# Epoch 41/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0875 - categorical_accuracy: 0.9649
# Epoch 42/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0826 - categorical_accuracy: 0.9649
# Epoch 43/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1123 - categorical_accuracy: 0.9509
# Epoch 44/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3186 - categorical_accuracy: 0.8947
# Epoch 45/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3111 - categorical_accuracy: 0.8912
# Epoch 46/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1738 - categorical_accuracy: 0.9333
# Epoch 47/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1168 - categorical_accuracy: 0.9614
# Epoch 48/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0743 - categorical_accuracy: 0.9825
# Epoch 49/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0689 - categorical_accuracy: 0.9789
# Epoch 50/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1309 - categorical_accuracy: 0.9579
# Epoch 51/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1319 - categorical_accuracy: 0.9263
# Epoch 52/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1023 - categorical_accuracy: 0.9614
# Epoch 53/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1303 - categorical_accuracy: 0.9404
# Epoch 54/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1205 - categorical_accuracy: 0.9649
# Epoch 55/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0699 - categorical_accuracy: 0.9825
# Epoch 56/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0721 - categorical_accuracy: 0.9754
# Epoch 57/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0807 - categorical_accuracy: 0.9684
# Epoch 58/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0829 - categorical_accuracy: 0.9649
# Epoch 59/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1269 - categorical_accuracy: 0.9474
# Epoch 60/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0992 - categorical_accuracy: 0.9649
# Epoch 61/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1339 - categorical_accuracy: 0.9579
# Epoch 62/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1568 - categorical_accuracy: 0.9404
# Epoch 63/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2128 - categorical_accuracy: 0.9333
# Epoch 64/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2409 - categorical_accuracy: 0.9298
# Epoch 65/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2850 - categorical_accuracy: 0.9158
# Epoch 66/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1560 - categorical_accuracy: 0.9368
# Epoch 67/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1479 - categorical_accuracy: 0.9579
# Epoch 68/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1036 - categorical_accuracy: 0.9649
# Epoch 69/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0656 - categorical_accuracy: 0.9719
# Epoch 70/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0473 - categorical_accuracy: 0.9895
# Epoch 71/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0409 - categorical_accuracy: 0.9895
# Epoch 72/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0669 - categorical_accuracy: 0.9719
# Epoch 73/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0685 - categorical_accuracy: 0.9754
# Epoch 74/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0636 - categorical_accuracy: 0.9789
# Epoch 75/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1296 - categorical_accuracy: 0.9579
# Epoch 76/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1527 - categorical_accuracy: 0.9544
# Epoch 77/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1191 - categorical_accuracy: 0.9544
# Epoch 78/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1264 - categorical_accuracy: 0.9474
# Epoch 79/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1061 - categorical_accuracy: 0.9825
# Epoch 80/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0993 - categorical_accuracy: 0.9684
# Epoch 81/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0631 - categorical_accuracy: 0.9825
# Epoch 82/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0581 - categorical_accuracy: 0.9684
# Epoch 83/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0946 - categorical_accuracy: 0.9684
# Epoch 84/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0571 - categorical_accuracy: 0.9789
# Epoch 85/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0451 - categorical_accuracy: 0.9860
# Epoch 86/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0317 - categorical_accuracy: 0.9965
# Epoch 87/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0283 - categorical_accuracy: 0.9930
# Epoch 88/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0183 - categorical_accuracy: 0.9965
# Epoch 89/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0199 - categorical_accuracy: 0.9930
# Epoch 90/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0499 - categorical_accuracy: 0.9895
# Epoch 91/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1464 - categorical_accuracy: 0.9684
# Epoch 92/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1233 - categorical_accuracy: 0.9579
# Epoch 93/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0775 - categorical_accuracy: 0.9754
# Epoch 94/1500
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0813 - categorical_accuracy: 0.9754
# Epoch 95/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0398 - categorical_accuracy: 0.9895
# Epoch 96/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0318 - categorical_accuracy: 0.9930
# Epoch 97/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0358 - categorical_accuracy: 0.9895
# Epoch 98/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0628 - categorical_accuracy: 0.9754
# Epoch 99/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0377 - categorical_accuracy: 0.9860
# Epoch 100/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0475 - categorical_accuracy: 0.9789
# Epoch 101/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0293 - categorical_accuracy: 0.9930
# Epoch 102/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0330 - categorical_accuracy: 0.9930
# Epoch 103/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0204 - categorical_accuracy: 0.9965
# Epoch 104/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0221 - categorical_accuracy: 0.9965
# Epoch 105/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0151 - categorical_accuracy: 0.9965
# Epoch 106/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0185 - categorical_accuracy: 0.9965
# Epoch 107/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0158 - categorical_accuracy: 0.9965
# Epoch 108/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0153 - categorical_accuracy: 0.9965
# Epoch 109/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0184 - categorical_accuracy: 0.9930
# Epoch 110/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1350 - categorical_accuracy: 0.9649
# Epoch 111/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4273 - categorical_accuracy: 0.9088
# Epoch 112/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6696 - categorical_accuracy: 0.8526
# Epoch 113/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4386 - categorical_accuracy: 0.8561
# Epoch 114/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2737 - categorical_accuracy: 0.9088
# Epoch 115/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2125 - categorical_accuracy: 0.9439
# Epoch 116/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1376 - categorical_accuracy: 0.9544
# Epoch 117/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1791 - categorical_accuracy: 0.9439
# Epoch 118/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2403 - categorical_accuracy: 0.9018
# Epoch 119/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1786 - categorical_accuracy: 0.9333
# Epoch 120/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1154 - categorical_accuracy: 0.9509
# Epoch 121/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1179 - categorical_accuracy: 0.9614
# Epoch 122/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0859 - categorical_accuracy: 0.9719
# Epoch 123/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0931 - categorical_accuracy: 0.9684
# Epoch 124/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0833 - categorical_accuracy: 0.9649
# Epoch 125/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0867 - categorical_accuracy: 0.9649
# Epoch 126/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0995 - categorical_accuracy: 0.9649
# Epoch 127/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0571 - categorical_accuracy: 0.9754
# Epoch 128/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1220 - categorical_accuracy: 0.9649
# Epoch 129/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1344 - categorical_accuracy: 0.9544
# Epoch 130/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0812 - categorical_accuracy: 0.9860
# Epoch 131/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0565 - categorical_accuracy: 0.9860
# Epoch 132/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0289 - categorical_accuracy: 0.9930
# Epoch 133/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0236 - categorical_accuracy: 0.9965
# Epoch 134/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0204 - categorical_accuracy: 0.9965
# Epoch 135/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0171 - categorical_accuracy: 0.9965
# Epoch 136/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0161 - categorical_accuracy: 0.9965
# Epoch 137/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0174 - categorical_accuracy: 0.9965
# Epoch 138/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0170 - categorical_accuracy: 0.9965
# Epoch 139/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0180 - categorical_accuracy: 0.9965
# Epoch 140/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0170 - categorical_accuracy: 0.9965
# Epoch 141/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0156 - categorical_accuracy: 0.9965
# Epoch 142/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0156 - categorical_accuracy: 0.9965
# Epoch 143/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0207 - categorical_accuracy: 0.9930
# Epoch 144/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0152 - categorical_accuracy: 0.9965
# Epoch 145/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0148 - categorical_accuracy: 0.9965
# Epoch 146/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0145 - categorical_accuracy: 0.9965
# Epoch 147/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0134 - categorical_accuracy: 0.9965
# Epoch 148/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0125 - categorical_accuracy: 0.9965
# Epoch 149/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0115 - categorical_accuracy: 0.9965
# Epoch 150/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0116 - categorical_accuracy: 0.9965
# Epoch 151/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0121 - categorical_accuracy: 0.9965
# Epoch 152/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0109 - categorical_accuracy: 0.9965
# Epoch 153/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0104 - categorical_accuracy: 0.9965
# Epoch 154/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0082 - categorical_accuracy: 0.9965
# Epoch 155/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0079 - categorical_accuracy: 0.9965
# Epoch 156/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0051 - categorical_accuracy: 1.0000
# Epoch 157/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0331 - categorical_accuracy: 0.9965
# Epoch 158/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0247 - categorical_accuracy: 0.9930
# Epoch 159/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0534 - categorical_accuracy: 0.9860
# Epoch 160/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1191 - categorical_accuracy: 0.9684
# Epoch 161/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1007 - categorical_accuracy: 0.9614
# Epoch 162/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0698 - categorical_accuracy: 0.9719
# Epoch 163/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0507 - categorical_accuracy: 0.9895
# Epoch 164/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0610 - categorical_accuracy: 0.9860
# Epoch 165/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0579 - categorical_accuracy: 0.9789
# Epoch 166/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0397 - categorical_accuracy: 0.9825
# Epoch 167/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0369 - categorical_accuracy: 0.9895
# Epoch 168/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1307 - categorical_accuracy: 0.9614
# Epoch 169/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1258 - categorical_accuracy: 0.9439
# Epoch 170/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1042 - categorical_accuracy: 0.9684
# Epoch 171/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3379 - categorical_accuracy: 0.9228
# Epoch 172/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4281 - categorical_accuracy: 0.8632
# Epoch 173/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2990 - categorical_accuracy: 0.8947
# Epoch 174/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1816 - categorical_accuracy: 0.9368
# Epoch 175/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1707 - categorical_accuracy: 0.9368
# Epoch 176/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2508 - categorical_accuracy: 0.9368
# Epoch 177/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2446 - categorical_accuracy: 0.8982
# Epoch 178/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1496 - categorical_accuracy: 0.9228
# Epoch 179/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1422 - categorical_accuracy: 0.9474
# Epoch 180/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1396 - categorical_accuracy: 0.9439
# Epoch 181/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0706 - categorical_accuracy: 0.9789
# Epoch 182/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0463 - categorical_accuracy: 0.9895
# Epoch 183/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0969 - categorical_accuracy: 0.9754
# Epoch 184/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2449 - categorical_accuracy: 0.9228
# Epoch 185/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0943 - categorical_accuracy: 0.9825
# Epoch 186/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0768 - categorical_accuracy: 0.9825
# Epoch 187/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0450 - categorical_accuracy: 0.9895
# Epoch 188/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0455 - categorical_accuracy: 0.9895
# Epoch 189/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0224 - categorical_accuracy: 0.9965
# Epoch 190/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0234 - categorical_accuracy: 0.9930
# Epoch 191/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0179 - categorical_accuracy: 0.9965
# Epoch 192/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0227 - categorical_accuracy: 0.9930
# Epoch 193/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0328 - categorical_accuracy: 0.9860
# Epoch 194/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0568 - categorical_accuracy: 0.9684
# Epoch 195/1500
# 9/9 [==============================] - 0s 26ms/step - loss: 0.0238 - categorical_accuracy: 0.9930
# Epoch 196/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0220 - categorical_accuracy: 0.9965
# Epoch 197/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0190 - categorical_accuracy: 0.9965
# Epoch 198/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0174 - categorical_accuracy: 0.9965
# Epoch 199/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0181 - categorical_accuracy: 0.9965
# Epoch 200/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0155 - categorical_accuracy: 0.9965
# Epoch 201/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0180 - categorical_accuracy: 0.9930
# Epoch 202/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0137 - categorical_accuracy: 0.9965
# Epoch 203/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0252 - categorical_accuracy: 0.9895
# Epoch 204/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0265 - categorical_accuracy: 0.9930
# Epoch 205/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1036 - categorical_accuracy: 0.9684
# Epoch 206/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1714 - categorical_accuracy: 0.9404
# Epoch 207/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1676 - categorical_accuracy: 0.9368
# Epoch 208/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1137 - categorical_accuracy: 0.9509
# Epoch 209/1500
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0932 - categorical_accuracy: 0.9649
# Epoch 210/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0749 - categorical_accuracy: 0.9754
# Epoch 211/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0460 - categorical_accuracy: 0.9825
# Epoch 212/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0223 - categorical_accuracy: 0.9965
# Epoch 213/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0236 - categorical_accuracy: 0.9930
# Epoch 214/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0194 - categorical_accuracy: 0.9930
# Epoch 215/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0180 - categorical_accuracy: 0.9930
# Epoch 216/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0168 - categorical_accuracy: 0.9965
# Epoch 217/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0133 - categorical_accuracy: 0.9965
# Epoch 218/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0130 - categorical_accuracy: 0.9965
# Epoch 219/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0130 - categorical_accuracy: 0.9965
# Epoch 220/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0142 - categorical_accuracy: 0.9965
# Epoch 221/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0130 - categorical_accuracy: 0.9965
# Epoch 222/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0153 - categorical_accuracy: 0.9965
# Epoch 223/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0143 - categorical_accuracy: 0.9930
# Epoch 224/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0249 - categorical_accuracy: 0.9930
# Epoch 225/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0133 - categorical_accuracy: 0.9965
# Epoch 226/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0128 - categorical_accuracy: 0.9965
# Epoch 227/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0141 - categorical_accuracy: 0.9965
# Epoch 228/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0136 - categorical_accuracy: 0.9965
# Epoch 229/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0159 - categorical_accuracy: 0.9930
# Epoch 230/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0287 - categorical_accuracy: 0.9930
# Epoch 231/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1045 - categorical_accuracy: 0.9509
# Epoch 232/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1423 - categorical_accuracy: 0.9614
# Epoch 233/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1501 - categorical_accuracy: 0.9404
# Epoch 234/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0741 - categorical_accuracy: 0.9789
# Epoch 235/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0329 - categorical_accuracy: 0.9965
# Epoch 236/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0400 - categorical_accuracy: 0.9895
# Epoch 237/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0303 - categorical_accuracy: 0.9895
# Epoch 238/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.1033 - categorical_accuracy: 0.9649
# Epoch 239/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0490 - categorical_accuracy: 0.9825
# Epoch 240/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0857 - categorical_accuracy: 0.9754
# Epoch 241/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0382 - categorical_accuracy: 0.9895
# Epoch 242/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0191 - categorical_accuracy: 0.9965
# Epoch 243/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0205 - categorical_accuracy: 0.9965
# Epoch 244/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0157 - categorical_accuracy: 0.9965
# Epoch 245/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0135 - categorical_accuracy: 0.9965
# Epoch 246/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0172 - categorical_accuracy: 0.9930
# Epoch 247/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0118 - categorical_accuracy: 0.9965
# Epoch 248/1500
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0117 - categorical_accuracy: 0.9965
# Epoch 249/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0134 - categorical_accuracy: 0.9965
# Epoch 250/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0104 - categorical_accuracy: 0.9965
# Epoch 251/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0116 - categorical_accuracy: 0.9965
# Epoch 252/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0118 - categorical_accuracy: 0.9930
# Epoch 253/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0090 - categorical_accuracy: 0.9965
# Epoch 254/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0139 - categorical_accuracy: 0.9965
# Epoch 255/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0151 - categorical_accuracy: 0.9930
# Epoch 256/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0254 - categorical_accuracy: 0.9895
# Epoch 257/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0203 - categorical_accuracy: 0.9895
# Epoch 258/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0144 - categorical_accuracy: 0.9965
# Epoch 259/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0144 - categorical_accuracy: 0.9965
# Epoch 260/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0100 - categorical_accuracy: 0.9965
# Epoch 261/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0105 - categorical_accuracy: 0.9965
# Epoch 262/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0102 - categorical_accuracy: 0.9965
# Epoch 263/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0073 - categorical_accuracy: 0.9965
# Epoch 264/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0071 - categorical_accuracy: 0.9965
# Epoch 265/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0100 - categorical_accuracy: 0.9965
# Epoch 266/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0633 - categorical_accuracy: 0.9754
# Epoch 267/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1093 - categorical_accuracy: 0.9649
# Epoch 268/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0750 - categorical_accuracy: 0.9719
# Epoch 269/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0712 - categorical_accuracy: 0.9825
# Epoch 270/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.2603 - categorical_accuracy: 0.9263
# Epoch 271/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0716 - categorical_accuracy: 0.9825
# Epoch 272/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1139 - categorical_accuracy: 0.9684
# Epoch 273/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0665 - categorical_accuracy: 0.9825
# Epoch 274/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0217 - categorical_accuracy: 0.9965
# Epoch 275/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0308 - categorical_accuracy: 0.9895
# Epoch 276/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0242 - categorical_accuracy: 0.9930
# Epoch 277/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0356 - categorical_accuracy: 0.9825
# Epoch 278/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0302 - categorical_accuracy: 0.9895
# Epoch 279/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0248 - categorical_accuracy: 0.9895
# Epoch 280/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0436 - categorical_accuracy: 0.9860
# Epoch 281/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0331 - categorical_accuracy: 0.9860
# Epoch 282/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0272 - categorical_accuracy: 0.9895
# Epoch 283/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0211 - categorical_accuracy: 0.9930
# Epoch 284/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0172 - categorical_accuracy: 0.9965
# Epoch 285/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0313 - categorical_accuracy: 0.9860
# Epoch 286/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0530 - categorical_accuracy: 0.9789
# Epoch 287/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0407 - categorical_accuracy: 0.9860
# Epoch 288/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0250 - categorical_accuracy: 0.9965
# Epoch 289/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0140 - categorical_accuracy: 0.9965
# Epoch 290/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0130 - categorical_accuracy: 0.9965
# Epoch 291/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0126 - categorical_accuracy: 0.9965
# Epoch 292/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0116 - categorical_accuracy: 0.9965
# Epoch 293/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0130 - categorical_accuracy: 0.9965
# Epoch 294/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0105 - categorical_accuracy: 0.9965
# Epoch 295/1500
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0119 - categorical_accuracy: 0.9965
# Epoch 296/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0094 - categorical_accuracy: 0.9965
# Epoch 297/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0105 - categorical_accuracy: 0.9965
# Epoch 298/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0102 - categorical_accuracy: 0.9965
# Epoch 299/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0091 - categorical_accuracy: 0.9965
# Epoch 300/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0085 - categorical_accuracy: 0.9965
# Epoch 301/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0093 - categorical_accuracy: 0.9965
# Epoch 302/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0081 - categorical_accuracy: 0.9965
# Epoch 303/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0070 - categorical_accuracy: 0.9965
# Epoch 304/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0074 - categorical_accuracy: 0.9965
# Epoch 305/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0121 - categorical_accuracy: 0.9930
# Epoch 306/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0047 - categorical_accuracy: 0.9965
# Epoch 307/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1494 - categorical_accuracy: 0.9754
# Epoch 308/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2364 - categorical_accuracy: 0.9404
# Epoch 309/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3821 - categorical_accuracy: 0.8632
# Epoch 310/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3428 - categorical_accuracy: 0.8807
# Epoch 311/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2002 - categorical_accuracy: 0.9474
# Epoch 312/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.1646 - categorical_accuracy: 0.9579
# Epoch 313/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0781 - categorical_accuracy: 0.9789
# Epoch 314/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0604 - categorical_accuracy: 0.9860
# Epoch 315/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0412 - categorical_accuracy: 0.9895
# Epoch 316/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0911 - categorical_accuracy: 0.9754
# Epoch 317/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.2547 - categorical_accuracy: 0.9439
# Epoch 318/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1227 - categorical_accuracy: 0.9719
# Epoch 319/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0839 - categorical_accuracy: 0.9825
# Epoch 320/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0412 - categorical_accuracy: 0.9930
# Epoch 321/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0265 - categorical_accuracy: 0.9965
# Epoch 322/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0170 - categorical_accuracy: 0.9965
# Epoch 323/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0164 - categorical_accuracy: 0.9965
# Epoch 324/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0156 - categorical_accuracy: 0.9965
# Epoch 325/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0147 - categorical_accuracy: 0.9965
# Epoch 326/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0149 - categorical_accuracy: 0.9965
# Epoch 327/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0144 - categorical_accuracy: 0.9965
# Epoch 328/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0141 - categorical_accuracy: 0.9965
# Epoch 329/1500
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0138 - categorical_accuracy: 0.9965
# Epoch 330/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0139 - categorical_accuracy: 0.9965
# Epoch 331/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0144 - categorical_accuracy: 0.9965
# Epoch 332/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0148 - categorical_accuracy: 0.9965
# Epoch 333/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0141 - categorical_accuracy: 0.9965
# Epoch 334/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0134 - categorical_accuracy: 0.9965
# Epoch 335/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0129 - categorical_accuracy: 0.9965
# Epoch 336/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0129 - categorical_accuracy: 0.9965
# Epoch 337/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0127 - categorical_accuracy: 0.9965
# Epoch 338/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0128 - categorical_accuracy: 0.9965
# Epoch 339/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0117 - categorical_accuracy: 0.9965
# Epoch 340/1500
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0121 - categorical_accuracy: 0.9965
# Epoch 341/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0121 - categorical_accuracy: 0.9965
# Epoch 342/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0125 - categorical_accuracy: 0.9965
# Epoch 343/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0112 - categorical_accuracy: 0.9965
# Epoch 344/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0107 - categorical_accuracy: 0.9965
# Epoch 345/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0099 - categorical_accuracy: 0.9965
# Epoch 346/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0109 - categorical_accuracy: 0.9965
# Epoch 347/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0104 - categorical_accuracy: 0.9965
# Epoch 348/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0093 - categorical_accuracy: 0.9965
# Epoch 349/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1892 - categorical_accuracy: 0.9754
# Epoch 350/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.3536 - categorical_accuracy: 0.8947
# Epoch 351/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4564 - categorical_accuracy: 0.8772
# Epoch 352/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.3355 - categorical_accuracy: 0.9158
# Epoch 353/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1866 - categorical_accuracy: 0.9404
# Epoch 354/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0979 - categorical_accuracy: 0.9684
# Epoch 355/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0982 - categorical_accuracy: 0.9825
# Epoch 356/1500
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0600 - categorical_accuracy: 0.9789
# Epoch 357/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0648 - categorical_accuracy: 0.9860
# Epoch 358/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0512 - categorical_accuracy: 0.9825
# Epoch 359/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0657 - categorical_accuracy: 0.9825
# Epoch 360/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0435 - categorical_accuracy: 0.9860
# Epoch 361/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0308 - categorical_accuracy: 0.9930
# Epoch 362/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0366 - categorical_accuracy: 0.9930
# Epoch 363/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0278 - categorical_accuracy: 0.9930
# Epoch 364/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0167 - categorical_accuracy: 0.9965
# Epoch 365/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0412 - categorical_accuracy: 0.9860
# Epoch 366/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0150 - categorical_accuracy: 0.9965
# Epoch 367/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0133 - categorical_accuracy: 0.9965
# Epoch 368/1500
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0124 - categorical_accuracy: 0.9965
# Epoch 369/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0110 - categorical_accuracy: 0.9965
# Epoch 370/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0107 - categorical_accuracy: 0.9965
# Epoch 371/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0096 - categorical_accuracy: 0.9965
# Epoch 372/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0087 - categorical_accuracy: 0.9965
# Epoch 373/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0084 - categorical_accuracy: 0.9965
# Epoch 374/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0072 - categorical_accuracy: 0.9965
# Epoch 375/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0059 - categorical_accuracy: 0.9965
# Epoch 376/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0092 - categorical_accuracy: 0.9965
# Epoch 377/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0330 - categorical_accuracy: 0.9860
# Epoch 378/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0158 - categorical_accuracy: 0.9895
# Epoch 379/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 0.0081 - categorical_accuracy: 0.9965
# Epoch 380/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0104 - categorical_accuracy: 0.9930
# Epoch 381/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0075 - categorical_accuracy: 0.9965
# Epoch 382/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 383/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0175 - categorical_accuracy: 0.9965
# Epoch 384/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0151 - categorical_accuracy: 0.9930
# Epoch 385/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0085 - categorical_accuracy: 0.9965
# Epoch 386/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0063 - categorical_accuracy: 0.9965
# Epoch 387/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 388/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0063 - categorical_accuracy: 0.9965
# Epoch 389/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0371 - categorical_accuracy: 0.9895
# Epoch 390/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1040 - categorical_accuracy: 0.9684
# Epoch 391/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0825 - categorical_accuracy: 0.9754
# Epoch 392/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0841 - categorical_accuracy: 0.9754
# Epoch 393/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.1372 - categorical_accuracy: 0.9509
# Epoch 394/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.1442 - categorical_accuracy: 0.9368
# Epoch 395/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1111 - categorical_accuracy: 0.9684
# Epoch 396/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0945 - categorical_accuracy: 0.9719
# Epoch 397/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0636 - categorical_accuracy: 0.9825
# Epoch 398/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.1591 - categorical_accuracy: 0.9368
# Epoch 399/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0916 - categorical_accuracy: 0.9684
# Epoch 400/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 0.0360 - categorical_accuracy: 0.9895
# Epoch 401/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0347 - categorical_accuracy: 0.9895
# Epoch 402/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0220 - categorical_accuracy: 0.9930
# Epoch 403/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0171 - categorical_accuracy: 0.9930
# Epoch 404/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0247 - categorical_accuracy: 0.9895
# Epoch 405/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0144 - categorical_accuracy: 0.9965
# Epoch 406/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0141 - categorical_accuracy: 0.9965
# Epoch 407/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0317 - categorical_accuracy: 0.9895
# Epoch 408/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0640 - categorical_accuracy: 0.9719
# Epoch 409/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0207 - categorical_accuracy: 0.9930
# Epoch 410/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0149 - categorical_accuracy: 0.9965
# Epoch 411/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0123 - categorical_accuracy: 0.9965
# Epoch 412/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0113 - categorical_accuracy: 0.9965
# Epoch 413/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0096 - categorical_accuracy: 0.9965
# Epoch 414/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 0.0077 - categorical_accuracy: 0.9965
# Epoch 415/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0061 - categorical_accuracy: 0.9965
# Epoch 416/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0053 - categorical_accuracy: 1.0000
# Epoch 417/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0105 - categorical_accuracy: 0.9965
# Epoch 418/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0083 - categorical_accuracy: 0.9965
# Epoch 419/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 0.0039 - categorical_accuracy: 1.0000
# Epoch 420/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 421/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 422/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 9.3091e-04 - categorical_accuracy: 1.0000
# Epoch 423/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 5.4115e-04 - categorical_accuracy: 1.0000
# Epoch 424/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 4.2046e-04 - categorical_accuracy: 1.0000
# Epoch 425/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.6633e-04 - categorical_accuracy: 1.0000
# Epoch 426/1500
# ...
# Epoch 1376/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1377/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1378/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1379/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1380/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1381/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.9736e-08 - categorical_accuracy: 1.0000
# Epoch 1382/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.9318e-08 - categorical_accuracy: 1.0000
# Epoch 1383/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.9318e-08 - categorical_accuracy: 1.0000
# Epoch 1384/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.9318e-08 - categorical_accuracy: 1.0000
# Epoch 1385/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.8900e-08 - categorical_accuracy: 1.0000
# Epoch 1386/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.8900e-08 - categorical_accuracy: 1.0000
# Epoch 1387/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.8900e-08 - categorical_accuracy: 1.0000
# Epoch 1388/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 3.8900e-08 - categorical_accuracy: 1.0000
# Epoch 1389/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.8482e-08 - categorical_accuracy: 1.0000
# Epoch 1390/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.8482e-08 - categorical_accuracy: 1.0000
# Epoch 1391/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.7645e-08 - categorical_accuracy: 1.0000
# Epoch 1392/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 3.7645e-08 - categorical_accuracy: 1.0000
# Epoch 1393/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.7645e-08 - categorical_accuracy: 1.0000
# Epoch 1394/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.7645e-08 - categorical_accuracy: 1.0000
# Epoch 1395/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.7645e-08 - categorical_accuracy: 1.0000
# Epoch 1396/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.7227e-08 - categorical_accuracy: 1.0000
# Epoch 1397/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.7227e-08 - categorical_accuracy: 1.0000
# Epoch 1398/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.7227e-08 - categorical_accuracy: 1.0000
# Epoch 1399/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 3.6390e-08 - categorical_accuracy: 1.0000
# Epoch 1400/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.6390e-08 - categorical_accuracy: 1.0000
# Epoch 1401/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.6390e-08 - categorical_accuracy: 1.0000
# Epoch 1402/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.6390e-08 - categorical_accuracy: 1.0000
# Epoch 1403/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.6390e-08 - categorical_accuracy: 1.0000
# Epoch 1404/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.5972e-08 - categorical_accuracy: 1.0000
# Epoch 1405/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.5554e-08 - categorical_accuracy: 1.0000
# Epoch 1406/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.5135e-08 - categorical_accuracy: 1.0000
# Epoch 1407/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.5135e-08 - categorical_accuracy: 1.0000
# Epoch 1408/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.5135e-08 - categorical_accuracy: 1.0000
# Epoch 1409/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.4717e-08 - categorical_accuracy: 1.0000
# Epoch 1410/1500
# 9/9 [==============================] - 0s 26ms/step - loss: 3.3881e-08 - categorical_accuracy: 1.0000
# Epoch 1411/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.3881e-08 - categorical_accuracy: 1.0000
# Epoch 1412/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.3881e-08 - categorical_accuracy: 1.0000
# Epoch 1413/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 3.3881e-08 - categorical_accuracy: 1.0000
# Epoch 1414/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.3462e-08 - categorical_accuracy: 1.0000
# Epoch 1415/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.3462e-08 - categorical_accuracy: 1.0000
# Epoch 1416/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.3044e-08 - categorical_accuracy: 1.0000
# Epoch 1417/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1418/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1419/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1420/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1421/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1422/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.2626e-08 - categorical_accuracy: 1.0000
# Epoch 1423/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.2207e-08 - categorical_accuracy: 1.0000
# Epoch 1424/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.2207e-08 - categorical_accuracy: 1.0000
# Epoch 1425/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 3.2207e-08 - categorical_accuracy: 1.0000
# Epoch 1426/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.2207e-08 - categorical_accuracy: 1.0000
# Epoch 1427/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.2207e-08 - categorical_accuracy: 1.0000
# Epoch 1428/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.1789e-08 - categorical_accuracy: 1.0000
# Epoch 1429/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 3.0534e-08 - categorical_accuracy: 1.0000
# Epoch 1430/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 3.0116e-08 - categorical_accuracy: 1.0000
# Epoch 1431/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 2.9698e-08 - categorical_accuracy: 1.0000
# Epoch 1432/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 2.9279e-08 - categorical_accuracy: 1.0000
# Epoch 1433/1500
# 9/9 [==============================] - 0s 27ms/step - loss: 2.9279e-08 - categorical_accuracy: 1.0000
# Epoch 1434/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 2.9279e-08 - categorical_accuracy: 1.0000
# Epoch 1435/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 2.9279e-08 - categorical_accuracy: 1.0000
# Epoch 1436/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 2.8861e-08 - categorical_accuracy: 1.0000
# Epoch 1437/1500
# 9/9 [==============================] - 0s 28ms/step - loss: 2.8443e-08 - categorical_accuracy: 1.0000
# Epoch 1438/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.8443e-08 - categorical_accuracy: 1.0000
# Epoch 1439/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 2.8443e-08 - categorical_accuracy: 1.0000
# Epoch 1440/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.8443e-08 - categorical_accuracy: 1.0000
# Epoch 1441/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 2.8025e-08 - categorical_accuracy: 1.0000
# Epoch 1442/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 2.7606e-08 - categorical_accuracy: 1.0000
# Epoch 1443/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.7606e-08 - categorical_accuracy: 1.0000
# Epoch 1444/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.7606e-08 - categorical_accuracy: 1.0000
# Epoch 1445/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 2.7606e-08 - categorical_accuracy: 1.0000
# Epoch 1446/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.7606e-08 - categorical_accuracy: 1.0000
# Epoch 1447/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 2.7188e-08 - categorical_accuracy: 1.0000
# Epoch 1448/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 2.6770e-08 - categorical_accuracy: 1.0000
# Epoch 1449/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 2.6770e-08 - categorical_accuracy: 1.0000
# Epoch 1450/1500
# 9/9 [==============================] - 0s 29ms/step - loss: 2.6770e-08 - categorical_accuracy: 1.0000
# Epoch 1451/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.6352e-08 - categorical_accuracy: 1.0000
# Epoch 1452/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.6352e-08 - categorical_accuracy: 1.0000
# Epoch 1453/1500
# 9/9 [==============================] - 0s 31ms/step - loss: 2.6352e-08 - categorical_accuracy: 1.0000
# Epoch 1454/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.6352e-08 - categorical_accuracy: 1.0000
# Epoch 1455/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.5933e-08 - categorical_accuracy: 1.0000
# Epoch 1456/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 2.5515e-08 - categorical_accuracy: 1.0000
# Epoch 1457/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.5515e-08 - categorical_accuracy: 1.0000
# Epoch 1458/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.5515e-08 - categorical_accuracy: 1.0000
# Epoch 1459/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 2.5515e-08 - categorical_accuracy: 1.0000
# Epoch 1460/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.5515e-08 - categorical_accuracy: 1.0000
# Epoch 1461/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 2.5097e-08 - categorical_accuracy: 1.0000
# Epoch 1462/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 2.5097e-08 - categorical_accuracy: 1.0000
# Epoch 1463/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.4678e-08 - categorical_accuracy: 1.0000
# Epoch 1464/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.4678e-08 - categorical_accuracy: 1.0000
# Epoch 1465/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 2.4260e-08 - categorical_accuracy: 1.0000
# Epoch 1466/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 1467/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 1468/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3842e-08 - categorical_accuracy: 1.0000
# Epoch 1469/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1470/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1471/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1472/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1473/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1474/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1475/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.3424e-08 - categorical_accuracy: 1.0000
# Epoch 1476/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2587e-08 - categorical_accuracy: 1.0000
# Epoch 1477/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.2587e-08 - categorical_accuracy: 1.0000
# Epoch 1478/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 2.2169e-08 - categorical_accuracy: 1.0000
# Epoch 1479/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.1750e-08 - categorical_accuracy: 1.0000
# Epoch 1480/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1481/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1482/1500
# 9/9 [==============================] - 1s 56ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1483/1500
# 9/9 [==============================] - 0s 41ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1484/1500
# 9/9 [==============================] - 0s 39ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1485/1500
# 9/9 [==============================] - 0s 34ms/step - loss: 2.1332e-08 - categorical_accuracy: 1.0000
# Epoch 1486/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 2.0914e-08 - categorical_accuracy: 1.0000
# Epoch 1487/1500
# 9/9 [==============================] - 0s 40ms/step - loss: 2.0496e-08 - categorical_accuracy: 1.0000
# Epoch 1488/1500
# 9/9 [==============================] - 0s 39ms/step - loss: 2.0496e-08 - categorical_accuracy: 1.0000
# Epoch 1489/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 2.0496e-08 - categorical_accuracy: 1.0000
# Epoch 1490/1500
# 9/9 [==============================] - 0s 37ms/step - loss: 2.0496e-08 - categorical_accuracy: 1.0000
# Epoch 1491/1500
# 9/9 [==============================] - 0s 56ms/step - loss: 2.0077e-08 - categorical_accuracy: 1.0000
# Epoch 1492/1500
# 9/9 [==============================] - 0s 36ms/step - loss: 2.0077e-08 - categorical_accuracy: 1.0000
# Epoch 1493/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 1.9659e-08 - categorical_accuracy: 1.0000
# Epoch 1494/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 1.9659e-08 - categorical_accuracy: 1.0000
# Epoch 1495/1500
# 9/9 [==============================] - 0s 32ms/step - loss: 1.9241e-08 - categorical_accuracy: 1.0000
# Epoch 1496/1500
# 9/9 [==============================] - 0s 30ms/step - loss: 1.9241e-08 - categorical_accuracy: 1.0000
# Epoch 1497/1500
# 9/9 [==============================] - 0s 42ms/step - loss: 1.9241e-08 - categorical_accuracy: 1.0000
# Epoch 1498/1500
# 9/9 [==============================] - 0s 33ms/step - loss: 1.9241e-08 - categorical_accuracy: 1.0000
# Epoch 1499/1500
# 9/9 [==============================] - 0s 35ms/step - loss: 1.8823e-08 - categorical_accuracy: 1.0000
# Epoch 1500/1500
# 9/9 [==============================] - 0s 38ms/step - loss: 1.8823e-08 - categorical_accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 64)            82688
#
#  lstm_1 (LSTM)               (None, 10, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 237,350
# Trainable params: 237,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 629ms/step

# %%
actions[np.argmax(res[14])] #preliminary testing
# Out:
# 'take care'

# %%
actions[np.argmax(y_test[14])]
# Out:
# 'take care'

# %%
model.save('action.h5') #to be used in case of corruption

# %%
### STEP 9 ###
model.load('action.h5') #use to load in pre-trained model

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[11,  0],
#         [ 1,  3]],
#
#        [[10,  1],
#         [ 0,  4]],
#
#        [[13,  0],
#         [ 0,  2]],
#
#        [[13,  0],
#         [ 0,  2]],
#
#        [[14,  0],
#         [ 0,  1]],
#
#        [[13,  0],
#         [ 0,  2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9333333333333333

# %%
### STEP 10 ###
from scipy import stats

# %%
### STEP 11 ###
## Testing in real time
sequence = []
sentence = ""
predictions = []
threshold = 0.99

cap = cv2.VideoCapture(0)
# Set model 
with mpHolistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mp_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-10:]
        
        if len(sequence) == 10:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            #print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        # Display word on screen
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    sentence = actions[np.argmax(res)]
                    
                else: 
                    sentence = ""

            
        cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
